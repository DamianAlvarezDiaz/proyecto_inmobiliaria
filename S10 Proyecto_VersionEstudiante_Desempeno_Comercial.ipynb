# %% [markdown]
# # 📊 Proyecto: Dashboard de desempeño comercial 2024–2025
# Empresa: **Andes Retail Group**
#
# Este notebook servirá como guía estructurada para el desarrollo del proyecto.
# Sigue cada paso y espera feedback del evaluador.

# %% [markdown]
# ## 🔹 Paso 1: Conexión y Exploración
#
# - Importa el archivo excel en Power BI Desktop o en Tableau.
# - Revisa tipos de datos.
# - Identifica columnas clave.
# - Explora estructura general del dataset.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 2: Preparación de los datos
#
# - Cambia el formato de `Fecha_pedido` a español (Latinoamérica).
# - Corrige los **tipos de datos** de columnas numéricas.
# - Crea una columna condicional `Nivel_Venta` basada en `Ingresos`. Reglas:
#   - Si `Ingresos` es mayor o igual a 1000 → "Venta Alta"
#   - De lo contrario → "Venta Baja"
# - Activa **Vista Perfil de Columna** para validar calidad.
# - Deja el dataset listo para análisis.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 3: Diseño y planificación del Dashboard (antes y durante la construcción)
#
# - Define qué pregunta responde cada vista (Overview y Detalle).
# - Especifica qué KPIs incluirás y por qué.
# - Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Describe la jerarquía visual (qué verá primero el usuario).
#     - Indica cómo distribuirás los elementos en la página.
# - Especifica qué filtros o segmentadores usaras.

# %% [markdown]
# ### Diseño y planificación
# ✏️ Andes Retail Group tiene ya varias preguntas de negocio que desea responder, tales como
# - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
# - ¿Qué segmentos de clientes aportan mayor ingreso y rentabilidad?
# - ¿Qué categorías de producto tienen mayor impacto en el negocio?
# - ¿Existen diferencias relevantes entre países o regiones?
# - ¿Qué patrones temporales se observan a lo largo del año?
# - ¿Dónde podrían existir oportunidades de mejora comercial?
#
# Esto nos plantea la necesidad de comenzar filtrando por los años 2024 y 2025, segmentar pr clientes que aportan mayor ingreso y rentabilidad, encontrar las categorías de productos de mayor impacto, identificar si hay diferenciación geográfica, hallar patrones temporales e identificar áreas de oportunidad.
#
# Las columnas relevantes para el análisis serán "Fecha_Pedido", "Estación", "Segmento_Cliente", "Región", "País", "Categría_Producto", "Unidades_Vendidas", "Ingresos", "Costo" y "Precio_Unitario"
#
#
# #### Vista Overview - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
# Los siguientes KPIs se filtrarán por los años 2024 y 2025
# - Ingresos: La suma muestra el total de "Ingresos"
# - Cantidad de productos vendidos: muestra la suma de "Unidades_Vendidas"
# - Utilidad: se obtiene del campo agregado "Utilidad", producto de la resta de "Ingresos" menos "Costos" (rentabilidad)
#
#
#
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025? Se responderá con gráfico de líneas ("Ingresos" vs Mes/Año)
# - ¿Qué segmentos de clientes aportan mayor ingreso y rentabilidad? Gráfico de barras comparando "Utilidad" e "Ingresos" por segmento de cliente
# - ¿Qué categorías de producto tienen mayor impacto en el negocio? Gráfico de barras entre "Categoría_Producto" y "Utilidad"
# - ¿Existen diferencias relevantes entre países o regiones? Gráfico de barras con "País" según la "utilidad
#
# Descripción de la jerarquía visual:
# - Título: "Desempeño Andes Retail Group"
# - KPIs con métricas clave y Segmentador por Año
# - Gráfica de líneas que muestra la evolución a lo largo de los dos años (2024 y 2025)
# - Gráficos que responden a las otras preguntas de negocio
#
# Filtro(s)
# - Año: 2024 y 2025
# - Categoría de producto
# - Segmento de cliente
#
# #### Vista detalle - ¿Por qué se han caido/subido/mantenido los ingresos?
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico comparación estacional contra utilidad: Gráfico de líneas "Utilidad" por "País" contra "Estación" para ver cómo cambia a lo largo del tiempo
# - Gráfico comparación de Nuúmero de Pedidos: gráfico de líneas para ver cuántos pedidos hay por "País" a lo largo del tiempo
# - Gráfico comparación de "Unidades_Vendidas" en el tiempo: gráfico de líneas para contar unidades vendidas por "País" según la "Estación"
# - Comparación de la Utilidad Total según el segmento de cliente: gráfico de líneas de la "Utilidad" por país según el segmento del cliente
# - Comparativa de categoría de producto: gráfico de líneas para mostrar la "Utilidad" por "País" según la categoría del producto
# - Tabla mostrando 4-6 columnas:
#   - Estación del año
#   - País
#   - Suma de Utilidad
#   - Suma de Unidades Vendidas
#   - Segmento de Clienta
#
#
# Filtros (mínimo 2)
# - Año
# - Estación

# %% [markdown]
# ## 🔹 Paso 4: Crear visualizaciones efectivas
#
# - Construir Vista 1 (Overview Ejecutivo).
# - Construir Vista 2 (Análisis Detallado).
# - Asegurar claridad y coherencia visual.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 5: Narrativa con Modelo SCQA + mensaje asincrónico
#
# - Escribe la narrativa que
#   - refleja lo que se observa en la **Vista General (Overview)**.
#   - explica los hallazgos en la **Vista Detalle**.
# - Utiliza el modelo **SCQA (Situación, Complicación, Pregunta, Respuesta)**.
# - Mantén la narrativa clara, ejecutiva y breve.
# - Redacta un mensaje ejecutivo tipo Slack resumiendo el insight principal.

# %% [markdown]
# ### Narrativa del Dashboard (Modelo SCQA)
# Se describe de forma estructurada la historia completa del dashboard usando SCQA, incluyendo contexto, problemas detectados, preguntas de negocio y recomendaciones basadas en datos.

# %% [markdown]
# #### 🖥️ Vista General (Overview)
#
# **S (Situación):**
# En el Overview, el gráfico de líneas nos muestra que tanto en 2024 como en 2025 (y al unir los dos años también), hay una notoria caída en los meses de invierno.
#
# **C (Complicación):**
# Al ver los demás gráficos de barras, nos damos cuenta de que el segmento de cliente "Económico" y Colombia muestran valores por debajo del promedio
#
# **Q (Pregunta):**
# ¿Qué está pasando en el Invierno y cómo se distribuyen diferentes variables por país?
#
# **A (Respuesta):**
# Las ventas caen abruptamente en invierno y Colombia tiene niveles muy bajos en todas las categorías de productos
#
#
#
# #### 🔎 Vista Detalle
#
# **S (Situación):**
# Las tres regiones de Colombia tienen una utilidad total y una cantidad de unidades vendidas por debajo del promedio.
#
# **C (Complicación):**
# Los valores bajos de Colombia corresponden con mantener cantidades de pedidos muy por debajo de los otros dos países y del promedio.
# También vemos que el segmento "Económico" es muy bajo en los tres países
#
# **Q (Pregunta):**
# ¿Qué está causando las ventas bajas en Colombia y la debilidad en el segmento "Económico"?
#
# **A (Respuesta):**
# La estacionalidad influye, ya que notamos una caída en la utilidad y las unidades vendidas en todos los países, pero se deben tomar medidas y revisiones más detalladas respecto a lo que está pasando en Colombia en todas los categorías de productos y en particular con el segmentos "Económico" para todos los países.

# %% [markdown]
# ### Mensaje asincrónico para Slack (Modelo SCQA)
#
# Resume los insights más importantes en un mensaje breve.
# - Comunica impacto en negocio y acciones recomendadas, como si lo enviaras a stakeholders por Slack.
# - Escribe un mensaje directo y conciso.

# %% [markdown]
# **📊 Actualización desempeño comercial**
#
# Equipo, las ventas caen abrupamente en Invierno (Utilidad y Unidades Vendidas). Más preocupante es el mercado de Colombia, que tiene ventas muy bajas en todos los productos y se debe profundizar también en la debilidad de los clientes "económicos". Atención a marketing sobre estos focos rojos.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Incluye **una** de las siguientes opciones, según la herramienta que hayas utilizado:
# - 🔗 Link público del dashboard publicado (Power BI Service o Tableau Public), o
# - 🔗 Link público de Google Drive/OneDrive con el archivo `.pbix`, o
# - ✅ Confirmación de que el archivo `.pbix` fue subido como indica el screencast.
#
# ### 📎 Enlace del proyecto:

# %% [markdown]
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")

# %% [markdown]
# **NOTA: Se realizó el proyecto tanto en Power BI como en Tableau para practicar sobre ambas plataformas**
#
# **Encontré Power BI más sencilla de usar, por lo que SUBI MI PROYECTO A LA PLATAFORMA**

# %% [markdown]
# Para ver el proyecto en Power Bi, siga el siguiente enlace

# %% [markdown]
# https://drive.google.com/file/d/1xmd4tvRu-GCPFkQuozgiyeU6jLleIe0P/view?usp=sharing

# %% [markdown]
# Para ver el proyecto en Tableau Public, siga el siguiente enlace

# %% [markdown]
# https://drive.google.com/file/d/1UkA1QaPVbRweT9_huH4N_3YIvM3pRbzN/view?usp=drive_link

# %% [markdown]
# Para ir directamente a Tableau Public, siga el siguiente enlace

# %% [markdown]
# https://public.tableau.com/views/Proyecto9_JoseDamian_AlvarezDiazDeRivera/Dashboard_Detalles?:language=es-ES&publish=yes&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br><br>
#
# Hola, Jose. Realizaste un excelente trabajo.
#
# <b>Éxito.</b> El proyecto cumple con lo solicitado: el dashboard es funcional, coherente y comunica hallazgos accionables con datos bien preparados.<br><br>
#
# <b>1) Conexión de los datos</b><br>
# ✅ El objetivo esta muy bien logrado de la conexión de los datos de excel en Power BI, la cual carga sin errores. <br><br>
#
# <b>2) Preparación y calidad de datos (power query)</b><br>
# ✅ Se gestionan correctamente tipos de datos, los tipos de variables. Y creas las variables importantes para el análisis como la ganancia total y el nivel de venta<br><br>
#
# <b>3) Planificación y diseño</b><br>
# ✅ Los KPIs están bien seleccionados, correctamente calculados y alineados con el objetivo (incluye definiciones claras, unidades y periodos de referencia). Además, el orden en el que los colocas es correcta para llevar una secuencia lógica<br><br>
#
# <b>4) Análisis e insights</b><br>
# ✅ El análisis identifica patrones relevantes (tendencias, segmentos, outliers) y los interpreta con lógica de negocio. Los insights están respaldados por evidencia en el dashboard.<br><br>
#
# <b>5) Visualización y diseño del dashboard</b><br>
# ✅ Diseño limpio y legible: jerarquía visual adecuada, títulos informativos, etiquetas claras y filtros útiles (años). Las gráficas son apropiadas para cada métrica y no generan confusión. Muestras ls gráficos de tendencia temporal, comparación geografica, comparación de estación, detalles de ventas,  entre otros<br><br>
#
# <b>6) Interactividad y usabilidad</b><br>
# ✅ La navegación es intuitiva; los filtros responden como se espera y permiten explorar por dimensiones clave y hacer segmentación de los datos. El usuario puede llegar a conclusiones mediante las pestañas que agregas .<br><br>
#
# <b>7) Reproducibilidad y buenas prácticas</b><br>
# ✅ Código ordenado, con pasos claros, nombres consistentes y comentarios donde aportan valor. Estructura replicable (carga → limpieza → análisis → visualización).<br><br>
#
# Solamente en futuros casos puedes seguir explorando herramientas como conectar los filtros entre pestañas y gráficos por estaciones.
#
#
# <b>Resultado:</b> Proyecto aprobado. Excelente trabajo.
